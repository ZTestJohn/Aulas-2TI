# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dados = pd.read_csv("game")

dados.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                             Endereco              Skin  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Tempo Médio de Sessão (min)  Horas Mobile  Horas Web  \
# 0                    34.497268     12.655651  39.577668
# 1                    31.926272     11.109461  37.268959
# 2                    33.000915     11.330278  37.110597
# 3                    34.305557     13.717514  36.721283
# 4                    33.330673     12.795189  37.536653
#
#    Tempo de Jogo (meses)  Gastos Anuais (US$)
# 0               4.082621           587.951054
# 1               2.664034           392.204933
# 2               4.104543           487.547505
# 3               3.120179           581.852344
# 4               4.446308           599.406092

# %%
sns.jointplot(x="Horas Web", y="Gastos Anuais (US$)", data=dados, alpha=0.5)

# %%
sns.pairplot(
    dados,
    kind="scatter",
    plot_kws={"alpha": 0.4},
    diag_kws={"alpha": 0.55, "bins": 40}
)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Email                        500 non-null    object
#  1   Endereco                     500 non-null    object
#  2   Skin                         500 non-null    object
#  3   Tempo Médio de Sessão (min)  500 non-null    float64
#  4   Horas Mobile                 500 non-null    float64
#  5   Horas Web                    500 non-null    float64
#  6   Tempo de Jogo (meses)        500 non-null    float64
#  7   Gastos Anuais (US$)          500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
X = dados[
    [
        "Tempo Médio de Sessão (min)",
        "Horas Mobile", "Horas Web",
        "Tempo de Jogo (meses)"
    ]
]

y = dados["Gastos Anuais (US$)"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, test_size=0.3, 
                                                    random_state=42)

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()
