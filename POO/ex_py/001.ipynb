# %% [markdown]
# Desenvolva um programa python que tenha uma classe de objetos para armazenar
#  dados de músicas como nome, intérprete, compositor, gênero, ano, duração.
# O programa deverá perguntar ao usuário se ele deseja inserir, exibir, excluir
#  ou alterar uma música, se ele quiser inserir ele irá criar uma nova instância
#  do objeto e armazenar em um array, se ele quiser alterar, ele deverá digitar
#  o nome da música que deseja alterar, o programa deverá fazer uma busca no array
#   e então deixar o usuário alterar os dados da música solicitada, se ele quiser
#   excluir, realizará o mesmo processo de perguntar a música que deseja excluir,

# %%
print("hi")
# Out:
# Running cells with 'base (Python 3.12.8)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
